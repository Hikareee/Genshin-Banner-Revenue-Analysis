# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats

from sklearn.svm import SVC
from sklearn.metrics import accuracy_score as ac
from sklearn.model_selection import cross_val_score
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV

# %%
df=pd.read_excel("Genshin Impact Revenue.xlsx") #Dataset
df.dropna(inplace=True)

#Revenue class is divided into 'Above average'when revenue is above 20909226, otherwise, 'Below average'
#This number is taken from the added min and max point of the two clusters revenue which is then divided by 2 
df["Revenue Class"] = np.where(df["Revenue"]>20909226, "Above Average", "Below Average")

# %%
df.head(39)
# Out:
#     Version                            Version Name           Start Date  \
# 0       1.0                       Welcome to Tevyat           25/09/2020
# 1       1.0                       Welcome to Tevyat           20/10/2020
# 2       1.1                   A New Star Approaches  2020-11-11 00:00:00
# 3       1.1                   A New Star Approaches  2020-01-12 00:00:00
# 4       1.2         The Chalk Prince and the Dragon           23/12/2020
# 5       1.2         The Chalk Prince and the Dragon           13/01/2021
# 6       1.3                       All That Glitters  2021-03-02 00:00:00
# 7       1.3                       All That Glitters           18/02/2021
# 8       1.3                       All That Glitters  2021-03-03 00:00:00
# 9       1.4                 Invitation to Windblume           17/03/2021
# 10      1.4                 Invitation to Windblume  2021-07-04 00:00:00
# 11      1.5            Beneath the Light of Jadeite           28/04/2021
# 12      1.5            Beneath the Light of Jadeite           19/05/2021
# 13      1.6              Midsummer Island Adventure  2021-09-06 00:00:00
# 14      1.6              Midsummer Island Adventure           30/06/2021
# 15      2.0  Immovable God and the Eternal Euthymia           21/07/2021
# 16      2.0  Immovable God and the Eternal Euthymia  2021-11-08 00:00:00
# 17      2.1      Floating World Under the Moonlight  2021-01-09 00:00:00
# 18      2.1      Floating World Under the Moonlight           21/09/2021
# 19      2.2      Into the Perilous Labyrinth of Fog           13/10/2021
# 20      2.2      Into the Perilous Labyrinth of Fog  2021-02-11 00:00:00
# 21      2.3               Shadows Amidst Snowstorms           24/11/2021
# 22      2.3               Shadows Amidst Snowstorms           14/12/2021
# 23      2.4               Fleeting Colors in Flight  2022-05-01 00:00:00
# 24      2.4               Fleeting Colors in Flight           25/01/2022
# 25      2.5                   When the Sakura Bloom           16/02/2022
# 26      2.5                   When the Sakura Bloom  2022-08-03 00:00:00
# 27      2.6             Zephyr of the Violet Garden           30/03/2022
# 28      2.6             Zephyr of the Violet Garden           19/04/2022
# 29      2.7             Hidden Dreams in the Depths           31/05/2022
# 30      2.7             Hidden Dreams in the Depths           21/06/2022
# 31      2.8                         Summer Fantasia           13/07/2022
# 32      2.8                         Summer Fantasia  2022-02-08 00:00:00
# 33      3.0         The Morn A Thousand Roses Bring           24/08/2022
# 34      3.0         The Morn A Thousand Roses Bring  2022-09-09 00:00:00
# 35      3.1         King Deshret and The Three Magi           28/09/2022
# 36      3.1         King Deshret and The Three Magi           14/10/2022
# 37      3.2    Akasha Pulses, The Kalpa Flame Rises  2022-02-11 00:00:00
# 38      3.2    Akasha Pulses, The Kalpa Flame Rises           18/11/2022
#
#                End Date                             5 Star Characters  Rerun  \
# 0            19/10/2020                                         Venti    0.0
# 1   2020-10-11 00:00:00                                          Klee    0.0
# 2            30/11/2020                                     Tartaglia    0.0
# 3            22/12/2020                                       Zhongli    0.0
# 4   2021-12-01 00:00:00                                        Albedo    0.0
# 5   2021-02-02 00:00:00                                         Ganyu    0.0
# 6            17/02/2021                                          Xiao    0.0
# 7   2021-02-03 00:00:00                                        Keqing    0.0
# 8            16/03/2021                                        Hu Tao    0.0
# 16    0.0    1.0   8615144.0         21.0     4.102450e+05  Below Average
# 17    0.0    1.0  33020905.0         20.0     1.651045e+06  Above Average
# 18    0.0    1.0   7020975.0         22.0     3.191352e+05  Below Average
# 19    0.0    0.0   7785438.0         21.0     3.707351e+05  Below Average
# 20    0.0    1.0  25226952.0         22.0     1.146680e+06  Above Average
# 21    1.0    2.0  17026066.0         21.0     8.107650e+05  Below Average
# 22    0.0    0.0  13404072.0         22.0     6.092760e+05  Below Average
# 23    1.0    2.0  16994406.0         21.0     8.092574e+05  Below Average
# 24    1.0    2.0  26780298.0         22.0     1.217286e+06  Above Average
# 25    0.0    1.0  15110264.0         21.0     7.195364e+05  Below Average
# 26    1.0    1.0  33560259.0         22.0     1.525466e+06  Above Average
# 27    1.0    0.0  22767455.0         21.0     1.084165e+06  Above Average
# 28    0.0    1.0  35939066.0         43.0     8.357922e+05  Above Average
# 29    1.0    2.0  25612693.0         22.0     1.164213e+06  Above Average
# 30    0.0    0.0  12586764.0         22.0     5.721256e+05  Below Average
# 31    1.0    2.0  24808479.0         21.0     1.181356e+06  Above Average
# 32    1.0    1.0  14333266.0         22.0     6.515121e+05  Below Average
# 33    1.0    0.0  19068372.0         17.0     1.121669e+06  Below Average
# 34    1.0    1.0  15681840.0         19.0     8.253600e+05  Below Average
# 35    1.0    0.0  19052023.0         17.0     1.120707e+06  Below Average
# 36    1.0    2.0  15731680.0         17.0     9.253929e+05  Below Average
# 37    1.0    1.0  34017290.0         17.0     2.001017e+06  Above Average
# 38    1.0    2.0  14759312.0         19.0     7.768059e+05  Below Average

# %%
X.head(10) #features: rerun, mixed, gender, banner days
# Out:
#    Rerun  Mixed Gender  Banner Days
# 0    0.0    0.0    0.0         25.0
# 1    0.0    0.0    1.0         22.0
# 2    0.0    0.0    0.0         20.0
# 3    0.0    0.0    0.0         22.0
# 4    0.0    0.0    0.0         21.0
# 5    0.0    0.0    1.0         21.0
# 6    0.0    0.0    0.0         15.0
# 7    0.0    0.0    1.0         13.0
# 8    0.0    0.0    1.0         14.0
# 9    1.0    0.0    0.0         21.0

# %%
#Assign variables 
X=df.iloc[:,[5,6,7,9]]
y=df.loc[:,'Revenue Class']
print(X)
print(y)
# Out:
#     Rerun  Mixed Gender  Banner Days
# 0     0.0    0.0    0.0         25.0
# 1     0.0    0.0    1.0         22.0
# 2     0.0    0.0    0.0         20.0
# 3     0.0    0.0    0.0         22.0
# 4     0.0    0.0    0.0         21.0
# 5     0.0    0.0    1.0         21.0
# 6     0.0    0.0    0.0         15.0
# 7     0.0    0.0    1.0         13.0
# 8     0.0    0.0    1.0         14.0
# 9     1.0    0.0    0.0         21.0
# 10    1.0    0.0    0.0         21.0
# 11    1.0    0.0    0.0         21.0
# 12    0.0    0.0    1.0         21.0
# 13    1.0    0.0    1.0         21.0
# 14    0.0    0.0    0.0         21.0
# 15    0.0    0.0    1.0         21.0
# 16    0.0    0.0    1.0         21.0
# 17    0.0    0.0    1.0         20.0
# 18    0.0    0.0    1.0         22.0
# 19    1.0    0.0    0.0         21.0
# 20    1.0    0.0    1.0         22.0
# 21    1.0    1.0    2.0         21.0
# 22    0.0    0.0    0.0         22.0
# 23    1.0    1.0    2.0         21.0
# 24    1.0    1.0    2.0         22.0
# 25    0.0    0.0    1.0         21.0
# 26    1.0    1.0    1.0         22.0
# 27    2.0    1.0    0.0         21.0
# 28    1.0    0.0    1.0         43.0
# 29    2.0    1.0    2.0         22.0
# 30    1.0    0.0    0.0         22.0
# 31    1.0    1.0    2.0         21.0
# 32    1.0    1.0    1.0         22.0
# 33    2.0    1.0    0.0         17.0
# 34    1.0    1.0    1.0         19.0
# 35    2.0    1.0    0.0         17.0
# 36    2.0    1.0    2.0         17.0
# 37    2.0    1.0    1.0         17.0
# 38    1.0    1.0    2.0         19.0
# 0     Above Average
# 1     Above Average
# 2     Below Average
# 3     Below Average
# 4     Below Average
# 5     Below Average
# 6     Below Average
# 7     Below Average
# 8     Below Average
# 9     Below Average
# 10    Below Average
# 11    Below Average
# 12    Below Average
# 13    Below Average
# 14    Below Average
# 15    Below Average
# 16    Below Average
# 17    Above Average
# 18    Below Average
# 19    Below Average
# 20    Above Average
# 21    Below Average
# 22    Below Average
# 23    Below Average
# 24    Above Average
# 25    Below Average
# 26    Above Average
# 27    Above Average
# 28    Above Average
# 29    Above Average
# 30    Below Average
# 31    Above Average
# 32    Below Average
# 33    Below Average
# 34    Below Average
# 35    Below Average
# 36    Below Average
# 37    Above Average
# 38    Below Average
# Name: Revenue Class, dtype: object

# %%
#SVM Settings
svm = SVC(kernel='linear', random_state=1, gamma=2.0, C=20.8)
#2.0 gamma , 20.8 c accuracy score = 0.92
#cv result mean 0.67 with RBF
#cv result mean 0.78 with LINEAR

#Train the model
svm.fit(X, y)

#Predict X
y_pred=svm.predict(X)
#accurary score on trained data
print("Accuracy =", ac(y, y_pred))

#cross validation
cv_results = cross_val_score(svm, X, y, cv=15)
print("Cv Result =", cv_results)
print("Cv Result Mean =", np.mean(cv_results))
# Out:
# Accuracy = 0.8205128205128205
# Cv Result = [1.         0.66666667 0.66666667 0.66666667 1.         1.
#  0.66666667 1.         0.66666667 1.         0.         1.
#  0.5        1.         1.        ]
# Cv Result Mean = 0.7888888888888889
# C:\Users\tiffa\anaconda3\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 11 members, which is less than n_splits=15.
#   warnings.warn(

# %%
#Random Forest Classifier Settings
clf = RandomForestClassifier(max_depth=5, random_state=1)
#accuracy 0,79 but cv mean 0,74 very good

#Train the model
clf.fit(X, y)

#Predict X
y_pred=clf.predict(X)

print("Accuracy =", ac(y, y_pred))
cv_results = cross_val_score(clf, X, y, cv=15)

print("Cv Result =", cv_results)
print("Cv Result Mean =", np.mean(cv_results))
# Out:
# Accuracy = 0.8974358974358975
# C:\Users\tiffa\anaconda3\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 11 members, which is less than n_splits=15.
#   warnings.warn(
# Cv Result = [0.66666667 0.66666667 0.66666667 0.66666667 1.         0.66666667
#  0.66666667 0.66666667 1.         0.5        0.5        1.
#  0.5        1.         0.5       ]
# Cv Result Mean = 0.711111111111111

# %%
#The features that are used to predict the class revenue is X. 
#X has 4 features: Rerun, Mixed, Gender and Banner Days. 
#y is the class revenue label.
#The purpose is to see whether from the 4 features alone it can predict and classify whether the revenue will be above average/good or below average/bad. If so, we want to see how accurate our model is in classifying the revenue class based off those features and whether it can be considered a successful model or not.

#Results:
#when k= 15
#Using random forest classifier, it has a good cross validation result score of 0.71
#Using SVM with rbf as kernel, gamma 2.0 and C 20.8, it has a decent cross validation score of 0.67 
#Using SVM with linear as kernel, gamma 2.0 and C 20.8, it has a good mean crosss validation score of 0.78

#Thus the most optimal results is to use SVM linear.
