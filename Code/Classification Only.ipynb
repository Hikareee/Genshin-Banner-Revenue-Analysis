# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats

from sklearn.svm import SVC
from sklearn.metrics import accuracy_score as ac
from sklearn.model_selection import cross_val_score
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split

# %%
df=pd.read_excel("Genshin Impact Revenue.xlsx") #Dataset
df.dropna(inplace=True)

#Revenue class is divided into 'Above average' (revenue > average revenue), 'Below average'
df["Revenue Class"] = np.where(df["Revenue"]>df["Revenue"].mean(), "Above Average", "Below Average")

# %%
X.head(10) #features: rerun, mixed, gender, banner days
# Out:
#    Rerun  Mixed Gender  Banner Days
# 0    0.0    0.0    0.0         25.0
# 1    0.0    0.0    1.0         22.0
# 2    0.0    0.0    0.0         20.0
# 3    0.0    0.0    0.0         22.0
# 4    0.0    0.0    0.0         21.0
# 5    0.0    0.0    1.0         21.0
# 6    0.0    0.0    0.0         15.0
# 7    0.0    0.0    1.0         13.0
# 8    0.0    0.0    1.0         14.0
# 9    1.0    0.0    0.0         21.0

# %%
#Assign variables 
X=df.iloc[:,[5,6,7,9]]
y=df.loc[:,'Revenue Class']
print(X)
print(y)
# Out:
#     Rerun  Mixed Gender  Banner Days
# 0     0.0    0.0    0.0         25.0
# 1     0.0    0.0    1.0         22.0
# 2     0.0    0.0    0.0         20.0
# 3     0.0    0.0    0.0         22.0
# 4     0.0    0.0    0.0         21.0
# 5     0.0    0.0    1.0         21.0
# 6     0.0    0.0    0.0         15.0
# 7     0.0    0.0    1.0         13.0
# 8     0.0    0.0    1.0         14.0
# 9     1.0    0.0    0.0         21.0
# 10    1.0    0.0    0.0         21.0
# 11    1.0    0.0    0.0         21.0
# 12    0.0    0.0    1.0         21.0
# 13    1.0    0.0    1.0         21.0
# 14    0.0    0.0    0.0         21.0
# 15    0.0    0.0    1.0         21.0
# 16    0.0    0.0    1.0         21.0
# 17    0.0    0.0    1.0         20.0
# 18    0.0    0.0    1.0         22.0
# 19    1.0    0.0    0.0         21.0
# 20    1.0    0.0    1.0         22.0
# 21    1.0    1.0    2.0         21.0
# 22    0.0    0.0    0.0         22.0
# 23    1.0    1.0    2.0         21.0
# 24    1.0    1.0    2.0         22.0
# 25    0.0    0.0    1.0         21.0
# 26    1.0    1.0    1.0         22.0
# 27    2.0    1.0    0.0         21.0
# 28    1.0    0.0    1.0         43.0
# 29    2.0    1.0    2.0         22.0
# 30    1.0    0.0    0.0         22.0
# 31    1.0    1.0    2.0         21.0
# 32    1.0    1.0    1.0         22.0
# 33    2.0    1.0    0.0         17.0
# 34    1.0    1.0    1.0         19.0
# 35    2.0    1.0    0.0         17.0
# 36    2.0    1.0    2.0         17.0
# 37    2.0    1.0    1.0         17.0
# 38    1.0    1.0    2.0         19.0
# 0     Above Average
# 1     Above Average
# 2     Below Average
# 3     Below Average
# 4     Below Average
# 5     Below Average
# 6     Below Average
# 7     Below Average
# 8     Below Average
# 9     Below Average
# 10    Below Average
# 11    Below Average
# 12    Below Average
# 13    Below Average
# 14    Below Average
# 15    Below Average
# 16    Below Average
# 17    Above Average
# 18    Below Average
# 19    Below Average
# 20    Above Average
# 21    Below Average
# 22    Below Average
# 23    Below Average
# 24    Above Average
# 25    Below Average
# 26    Above Average
# 27    Above Average
# 28    Above Average
# 29    Above Average
# 30    Below Average
# 31    Above Average
# 32    Below Average
# 33    Above Average
# 34    Below Average
# 35    Above Average
# 36    Below Average
# 37    Above Average
# 38    Below Average
# Name: Revenue Class, dtype: object

# %%
#SVM Settings
svm = SVC(kernel='rbf', random_state=1, gamma=2.0, C=20.8)
#2.0 gamma , 20.8 c accuracy score = 0.92
#cv result mean 0.69

#Train the model
svm.fit(X, y)

#Predict X
y_pred=svm.predict(X)
#accurary score on trained data
print("Accuracy =", ac(y, y_pred))

#cross validation
cv_results = cross_val_score(svm, X, y, cv=6)
print("Cv Result =", cv_results)
print("Cv Result Mean =", np.mean(cv_results))
# Out:
# Accuracy = 0.9230769230769231
# Cv Result = [0.57142857 0.71428571 0.71428571 0.5        0.83333333 0.83333333]
# Cv Result Mean = 0.6944444444444445

# %%
#Random Forest Classifier Settings
clf = RandomForestClassifier(max_depth=2, random_state=0)
#accuracy 0,79 but cv mean 0,74 very good

#Train the model
clf.fit(X, y)

#Predict X
y_pred=clf.predict(X)

print("Accuracy =", ac(y, y_pred))
cv_results = cross_val_score(clf, X, y, cv=6)

print("Cv Result =", cv_results)
print("Cv Result Mean =", np.mean(cv_results))
# Out:
# Accuracy = 0.7948717948717948
# Cv Result = [0.57142857 0.71428571 0.85714286 0.83333333 0.83333333 0.66666667]
# Cv Result Mean = 0.746031746031746

# %% [raw]
# The features that are used to predict the class revenue is X.
# X has 4 features: Rerun, Mixed, Gender and Banner Days.
# y is the class revenue label.
# The purpose is to see whether from the 4 features alone it can predict and classify whether the revenue will be above average/good or below average/bad. If so, we want to see how accurate our model is in classifying the revenue class based off those features and whether it can be considered a successful model or not.
#
# Results:
# Using random forest classifier, it has a good cross validation result score of 0.74.
# Using SVM with rbf as kernel, gamma 2.0 and C 20.8, it has a decent cross validation score of 0.69
